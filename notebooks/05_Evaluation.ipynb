# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.evaluation.evaluate import evaluate_model
from src.data.tf_data import load_test_data
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Load Dataset

# %%
test_ds = load_test_data()

# %% [markdown]
# Run Evaluation

# %%
results = evaluate_model(model, test_ds)
results

# %% [markdown]
# Gender Confusion Matrix

# %%
cm = results["gender"]["confusion_matrix"]
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Gender Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# Ethnicity Confusion Matrix

# %%
cm = results["ethnicity"]["confusion_matrix"]
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Ethnicity Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# Age: Predicted vs Actual

# %%
y_true_age, _, _ = results["y_true"]
y_pred_age, _, _ = results["y_pred"]

plt.scatter(y_true_age, y_pred_age, s=3)
plt.xlabel("Actual Age")
plt.ylabel("Predicted Age")
plt.title("Age Regression: Predicted vs Actual")
plt.show()

# %% [markdown]
# Summary Printed in Notebook

# %%
print("AGE REGRESSION:", results["age"])
print("GENDER:", results["gender"])
print("ETHNICITY:", results["ethnicity"])
