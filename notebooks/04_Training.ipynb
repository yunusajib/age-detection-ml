# %% [markdown]
# Compile Model

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.models.multitask_cnn import build_multitask_model
import tensorflow as tf
model = build_multitask_model()

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss={
        "age_output": "mse",
        "ethnicity_output": "sparse_categorical_crossentropy",
        "gender_output": "sparse_categorical_crossentropy"
    },
    metrics={
        "age_output": "mae",
        "ethnicity_output": "accuracy",
        "gender_output": "accuracy"
    }
)

model.summary()
# Out:
# 2025-12-01 19:22:45.898192: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 24, 24,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ...

# %% [markdown]
# Load Dataset

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.data.tf_data import load_train_data, load_val_data
# Out:
# 2025-12-01 19:42:44.061098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
print("Notebook CWD:", os.getcwd())
print("train.csv exists:", os.path.exists("../data/processed/train.csv"))
print("val.csv exists:", os.path.exists("../data/processed/val.csv"))
print("test.csv exists:", os.path.exists("../data/processed/test.csv"))
# Out:
# Notebook CWD: /Users/yunusajib/Desktop/age-detection-ml/notebooks
# train.csv exists: True
# val.csv exists: True
# test.csv exists: True

# %%
from src.data.tf_data import load_train_data, load_val_data

train_ds = load_train_data()
val_ds = load_val_data()

# %%
for images, labels in train_ds.take(1):
    print("Images:", images.shape)
    print("Age:", labels["age"][:5])
    print("Ethnicity:", labels["ethnicity"][:5])
    print("Gender:", labels["gender"][:5])
# Out:
# Images: (32, 48, 48, 3)
# Age: tf.Tensor([13. 24. 12. 85. 26.], shape=(5,), dtype=float32)
# Ethnicity: tf.Tensor([0 3 0 0 3], shape=(5,), dtype=int32)
# Gender: tf.Tensor([0 1 0 1 1], shape=(5,), dtype=int32)
# 2025-12-01 19:43:33.265556: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
